# %% [markdown]
# <h1>Quiz 1 : Pemahaman Machine Learning</h1>
#
# Jawab/Kerjakan pertanyaan/perintah di bawah ini dengan bahasa kalian sendiri :
#
# - Apa itu machine learning?
# - Apa itu data feature dan data target
# - Apa Perbedaan Supervised Learning, dan Unsupervised Learning
# - Apa Jenis2 yang ada di dalam Supervised Learning? Jelaskan Perbedaannya!
# - Apa perbedaan Hyperparameter dan Parameter
# - Sebutkan step2 dalam mengapplikasikan algoritma apapun dalam machine learning

# %% [markdown]
# #....
# --- algoritma komputer yang mempelajari pola dari data yang dibnerikan sehingga daapt memberikan suatu model yang dapat memprediksikan sebuah keluaran tertentu berdasarkan pola data awal
#
# --- data feature berupa data independen yang digunakan sebagai informasi awal untuk sebuah model sedangkan data target ialah data dependen keluaran model yang akan dibuat setelah informasi dadta feature diinput ke dalam model
#
# --- SL ialah salah satu cara pembelajaran model machine leaning yang merujuk pada data-data dengan label tertentu, sedangkan USL merujuk pada data-data yang belum memiliki label
#
# --- dibagi menjadi dua, classification dan regresi. pada classification data berupa kategorikal sedangkan pada regresi data berupa bilangan kontinu
#
# --- pada dasarnya hyperparameter merupakakan subset dari parameter, dimana perbedaanya terletak pada hyperparameter nilai tidak terikat secara langsung kepada model lebih kepada optimasi sedangkan parameter sangat mendefinisikan model
#
# ---a. tentukan algoritma yang akan digunakan
#    b. tentukan hyperparameter untuk membuat model
#    c. pisahkan data fitur dan data target
#    d. training model dengan menggunakan metode fit()
#    e. evaluasi model dengan menggunakan predict() untuk SL dan untuk USL gunakan transform() dengan predict()

# %% [markdown]
# <h1>Quiz 2 : Pemahaman Machine Learning</h1>
#
# Pelajarilah secara garis besar suatu model/algoritma machine learning, kemudian applikasikan untuk membuat model bagi data (variable x, y) di bawah ini. kemudian buatlah prediksi terhadap data training dan data baru di interval 20-30.
#
# - Plot data asli, data hasil prediksi terhadap data training, data hasil prediksi terhadap data baru
# - Tunjukan beberapa parameter yang dimiliki model yang telah kalian buat

# %%
import matplotlib.pyplot as plt
import numpy as np

rng = np.random.RandomState(42)
x = 20 * rng.rand(50)
y = x**2 + 2 * x + - 1 + rng.randn(50)
x=x.reshape(-1,1)
#x_pred=20 * rng.rand(50)
#x_pred=x_pred.reshape(-1,1)

# %%
# data yang akan di prediksi
x_new = np.arange(20, 30, 0.5)
x_new=x_new.reshape(-1,1)
x_train = np.arange(0, 20, 0.4)
x_train=x_train.reshape(-1,1)
from sklearn.tree import DecisionTreeRegressor
model_dtr=DecisionTreeRegressor(random_state=42)
model_dtr.fit(x,y)
y_1=model_dtr.predict(x_train)
y_2=model_dtr.predict(x_new)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(x, y,color='b',label='Data Asli')
ax.scatter(x,y_1,color='y',label='Prediksi ')
ax.plot(x_new,y_2,marker='_',color='g',label='Prediksi terhadap data baru')
ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
plt.legend(loc='upper right',bbox_to_anchor=(1, 0.75))
plt.show()

# %%
tree.plot_tree(model_dtr, max_depth=3, fontsize=5)
plt.show()

# %% [markdown]
# Contoh Jawaban Hasil Pembuatan Model dengan Algoritma DecisionTreeRegressor (Jawaban tidak haru sama) :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Contoh Jawaban Parameters (Tidak Harus Sama) :
#
# - Feature Importance : array([1.])
# - n features : 1
#
# Tree Graph :
#
# ![image.png](attachment:image.png)
