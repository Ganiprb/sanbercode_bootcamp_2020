# %% [markdown]
# <h2>Tugas Harian No 1 : Pemahaman Component Matplotlib</h2>
#
# - Jelaskan apa itu Figure
# - Jelaskan apa itu Axis

# %% [markdown]
# figure adalah semacam kanvas atau lahan dimana kita akan memberikan grafik dan sumbu sehingga menghasilkan satu kesatuan grafik yang utuh
#
# axis adalah sumbu yang akan diberikan sesuai dengan data

# %% [markdown]
# <h2>Tugas Harian No 2 : Membuat Component Figure dan Axis</h2>
#
# - Buatlah Figure dan Axis kosong tanpa Data
# - Plot data di bawah ini dengan 2 cara, yaitu dengan membuat figure dan axis secara explicit dan Implicit

# %%
import numpy as np
import matplotlib.pyplot as plt

fig=plt.plot()
fig
plt.style.use('default')

x = np.linspace(0, 20, 100)
y = np.cos(x/2)

# %%
fig=plt.figure() #explicit
ax=fig.add_subplot()
ax.plot(x,y)
plt.show()

# %%
plt.plot(x,y) #implicit
plt.show()

# %% [markdown]
# Exected Output :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Expected Output :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <h2>Tugas Harian No 3 : Memasukan multiple data ke dalam satu axis</h2>
#
# - Plot ketiga data berikut ke dalam satu axis, dan gunakan seaborn style
# - save data tersebut dengan nama file bebas

# %%
x = np.linspace(0, 20, 100)
y = np.cos(x/2)
y2 = np.sin(x)
y3 = np.sin(2*x)

# %%
plt.style.use('seaborn')
fig, ax =plt.subplots()
ax.plot(x,y)
ax.plot(x,y2)
ax.plot(x,y3)
plt.show()

# %% [markdown]
# Expected Output :
#
# ![image.png](attachment:image.png)
